# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models # add models to the list
from torchvision.utils import make_grid
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
train_transform = transforms.Compose([
        transforms.RandomRotation(10),      # rotate +/- 10 degrees
        transforms.RandomHorizontalFlip(),  # reverse 50% of images
        transforms.Resize(224),             # resize shortest side to 224 pixels
        transforms.CenterCrop(224),         # crop longest side to 224 pixels at center
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

test_transform = transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])

# %%
root = 'Data'

total_data = datasets.ImageFolder(os.path.join(root, 'train'), transform=train_transform)
torch.manual_seed(42)

print(total_data)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 13452
#     Root location: Data/train
#     StandardTransform
# Transform: Compose(
#                RandomRotation(degrees=[-10.0, 10.0], interpolation=nearest, expand=False, fill=0)
#                RandomHorizontalFlip(p=0.5)
#                Resize(size=224, interpolation=bilinear)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
train_set, val_set , test_set= torch.utils.data.random_split(total_data, [11000,2000, 452])

train_loader = DataLoader(train_set, batch_size=10, shuffle=True)
validation_loader = DataLoader(val_set, batch_size=10, shuffle=True)

class_names = total_data.classes

print(class_names)
print(f'Training images available: {len(train_set)}')
print(f'Validation images available:  {len(val_set)}')
print(f'Test images available: {len(test_set)}')
# Out:
# ['100', '30', '50', '60', '70', '80', 'forward', 'left', 'right']
# Training images available: 11000
# Validation images available:  2000
# Test images available: 452

# %%
# Grab the first batch of 10 images
for images,labels in train_loader: 
    break

# Print the labels
print('Label:', labels.numpy())
print('Class:', *np.array([class_names[i] for i in labels]))

im = make_grid(images, nrow=5)  # the default nrow is 8

# Inverse normalize the images
inv_normalize = transforms.Normalize(
    mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
    std=[1/0.229, 1/0.224, 1/0.225]
)
im_inv = inv_normalize(im)

# Print the images
plt.figure(figsize=(12,4))
plt.imshow(np.transpose(im_inv.numpy(), (1, 2, 0)));
# Out:
# Label: [5 3 2 2 6 4 0 0 1 3]
# Class: 80 60 50 50 forward 70 100 100 30 60

# %%
class ConvolutionalNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 3, 1)
        self.conv2 = nn.Conv2d(6, 16, 3, 1)
        self.fc1 = nn.Linear(54*54*16, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, X):
        X = F.relu(self.conv1(X))
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X, 2, 2)
        X = X.view(-1, 54*54*16)
        X = F.relu(self.fc1(X))
        X = F.relu(self.fc2(X))
        X = self.fc3(X)
        return F.log_softmax(X, dim=1)

# %%
torch.manual_seed(101)
CNNmodel = ConvolutionalNetwork()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(CNNmodel.parameters(), lr=0.001)
CNNmodel
# Out:
# ConvolutionalNetwork(
#   (conv1): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=46656, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
def count_parameters(model):
    params = [p.numel() for p in model.parameters() if p.requires_grad]
    for item in params:
        print(f'{item:>8}')
    print(f'________\n{sum(params):>8}')

# %%
count_parameters(CNNmodel)
# Out:
#      162
#        6
#      864
#       16
#  5598720
#      120
#    10080
#       84
#      840
#       10
# ________
#  5610902

# %%
import time
start_time = time.time()

epochs = 10

max_trn_batch = len(train_set)/10
max_tst_batch = len(val_set)/10

train_losses = []
test_losses = []
train_correct = []
test_correct = []

for i in range(epochs):
    trn_corr = 0
    tst_corr = 0
    
    # Run the training batches
    for b, (X_train, y_train) in enumerate(train_loader):
        
        # Limit the number of batches
        if b == max_trn_batch:
            break
        b+=1
        
        # Apply the model
        y_pred = CNNmodel(X_train)
        loss = criterion(y_pred, y_train)
 
        # Tally the number of correct predictions
        predicted = torch.max(y_pred.data, 1)[1]
        batch_corr = (predicted == y_train).sum()
        trn_corr += batch_corr
        
        # Update parameters
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Print interim results
        if b%100 == 0:
            print(f'epoch: {i:2}  batch: {b:4} [{10*b:6}/{len(train_set)}]  loss: {loss.item():10.8f}  \
accuracy: {trn_corr.item()*100/(10*b):7.3f}%')

    train_losses.append(loss.item())
    train_correct.append(trn_corr)

    # Run the testing batches
    with torch.no_grad():
        for b, (X_test, y_test) in enumerate(validation_loader):
            # Limit the number of batches
            if b == max_tst_batch:
                break

            # Apply the model
            y_val = CNNmodel(X_test)

            # Tally the number of correct predictions
            predicted = torch.max(y_val.data, 1)[1] 
            tst_corr += (predicted == y_test).sum()

    loss = criterion(y_val, y_test).item()
    test_losses.append(loss)
    test_correct.append(tst_corr)

print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# epoch:  0  batch
# epoch:  9  batch:  700 [  7000/11000]  loss: 0.02795943  accuracy:  96.143%
# epoch:  9  batch:  800 [  8000/11000]  loss: 0.24900933  accuracy:  96.037%
# epoch:  9  batch:  900 [  9000/11000]  loss: 0.11882381  accuracy:  95.944%
# epoch:  9  batch: 1000 [ 10000/11000]  loss: 0.16133782  accuracy:  95.940%
# epoch:  9  batch: 1100 [ 11000/11000]  loss: 0.13955860  accuracy:  95.936%
#
# Duration: 2149 seconds

# %%
torch.save(CNNmodel.state_dict(), 'CustomImageCNNModel.pt')

# %%
plt.plot(train_losses, label='training loss')
plt.plot(test_losses, label='validation loss')
plt.title('Loss at the end of each epoch')
plt.legend();

# %%
plt.plot([t/1300 for t in train_correct], label='training accuracy')
plt.plot([t/100 for t in test_correct], label='validation accuracy')
plt.title('Accuracy at the end of each epoch')
plt.legend();

# %%
print(test_correct)
print(f'Test accuracy: {test_correct[-1].item()*100/1000:.3f}%')
# Out:
# [tensor(1296), tensor(1661), tensor(1755), tensor(1784), tensor(1843), tensor(1832), tensor(1806), tensor(1819), tensor(1850), tensor(1860)]
# Test accuracy: 186.000%

# %%
a=0
false=[]
for x in range(len(test_set)):
    
    CNNmodel.eval()
    with torch.no_grad():
        new_pred = CNNmodel(test_set[x][0].view(1,3,224,224)).argmax()
        a += (new_pred != test_set[x][1]).sum()
        print(x,f'Predicted value: {new_pred.item()} {test_set[x][1]} {class_names[new_pred.item()]}')
        if new_pred.item() != test_set[x][1]:
            false.append(x)
# Out:
# 0 Predicted value: 2 2 50
# 1 Predicted value: 3 3 60
# 2 Predicted value: 4 4 70
# 3 Predicted value: 2 2 50
# 4 Predicted value: 0 0 100
# 5 Predicted value: 1 1 30
# 6 Predicted value: 1 1 30
# 7 Predicted value: 1 1 30
# 8 Predicted value: 3 3 60
# 9 Predicted value: 2 2 50
# 10 Predicted value: 4 0 70
# 11 Predicted value: 6 6 forward
# 12 Predicted value: 2 2 50
# 13 Predicted value: 6 6 forward
# 14 Predicted value: 6 8 forward
# 15 Predicted value: 2 2 50
# 16 Predicted value: 5 5 80
# 17 Predicted value: 4 3 70
# 18 Predicted value: 7 7 left
# 19 Predicted value: 4 4 70
# 20 Predicted value: 1 1 30
# 21 Predicted value: 1 1 30
# 22 Predicted value: 2 2 50
# 23 Predicted value: 7 7 left
# 24 Predicted value: 2 2 50
# 25 Predicted value: 2 2 50
# 26 Predicted value: 7 6 left
# 27 Predicted value: 7 7 left
# 28 Predicted value: 5 5 80
# 29 Predicted value: 3 3 60
# 30 Predicted value: 6 6 forward
# 31 Predicted value: 1 1 30
# 32 Predicted value: 2 2 50
# 33 Predicted value: 4 4 70
# 34 Predicted value: 2 2 50
# 35 Predicted value: 4 4 70
# 36 Predicted value: 0 0 100
# 37 Predicted value: 8 8 right
# 38 Predicted value: 4 4 70
# 39 Predicted value: 1 1 30
# 40 Predicted value: 2 2 50
# 41 Predicted value: 4 4 70
# 42 Predicted value: 6 6 forward
# 43 Predicted value: 1 1 30
# 44 Predicted value: 5 5 80
# 45 Predicted value: 7 7 left
# 46 Predicted value: 7 7 left
# 47 Predicted value: 3 3 60
# 48 Predicted value: 5 5 80
# 49 Predicted value: 1 1 30
# 50 Predicted value: 3 3 60
# 51 Predicted value: 6 6 forward
# 52 Predicted value: 3 3 60
# 53 Predicted value: 4 4 70
# 54 Predicted value: 1 1 30
# 55 Predicted value: 2 2 50
# 56 Predicted value: 5 5 80
# 57 Predicted value: 7 7 left
# 58 Predicted value: 0 0 100
# 59 Predicted value: 6 6 forward
# 60 Predicted value: 2 2 50
# 61 Predicted value: 2 2 50
# 62 Predicted value: 2 2 50
# 63 Predicted value: 2 2 50
# 64 Predicted value: 4 4 70
# 65 Predicted value: 4 4 70
# 66 Predicted value: 5 5 80
# 67 Predicted value: 3 5 60
# 68 Predicted value: 6 6 forward
# 69 Predicted value: 4 4 70
# 70 Predicted value: 3 3 60
# 71 Predicted value: 4 4 70
# 72 Predicted value: 3 3 60
# 73 Predicted value: 2 2 50
# 74 Predicted value: 5 5 80
# 75 Predicted value: 2 5 50
# 76 Predicted value: 2 2 50
# 77 Predicted value: 2 2 50
# 78 Predicted value: 3 3 60
# 79 Predicted value: 1 1 30
# 80 Predicted value: 5 5 80
# 81 Predicted value: 2 2 50
# 82 Predicted value: 1 1 30
# 83 Predicted value: 0 0 100
# 84 Predicted value: 1 1 30
# 85 Predicted value: 4 4 70
# 86 Predicted value: 2 2 50
# 87 Predicted value: 1 1 30
# 88 Predicted value: 4 4 70
# 89 Predicted value: 0 0 100
# 90 Predicted value: 4 4 70
# 91 Predicted value: 5 5 80
# 92 Predicted value: 3 3 60
# 93 Predicted value: 1 1 30
# 94 Predicted value: 2 2 50
# 95 Predicted value: 1 5 30
# 96 Predicted value: 4 4 70
# 97 Predicted value: 3 3 60
# 98 Predicted value: 2 5 50
# 99 Predicted value: 1 1 30
# 100 Predicted value: 3 3 60
# 101 Predicted value: 0 0 100
# 102 Predicted value: 0 0 100
# 103 Predicted value: 4 4 70
# 104 Predicted value: 2 2 50
# 105 Predicted value: 6 6 forward
# 106 Predicted value: 2 3 50
# 107 Predicted value: 1 1 30
# 108 Predicted value: 4 4 70
# 109 Predicted value: 1 1 30
# 110 Predicted value: 6 6 forward
# 111 Predicted value: 5 5 80
# 112 Predicted value: 8 8 right
# 113 Predicted value: 4 4 70
# 114 Predicted value: 3 3 60
# 115 Predicted value: 2 2 50
# 116 Predicted value: 3 3 60
# 117 Predicted value: 0 0 100
# 118 Predicted value: 3 3 60
# 119 Predicted value: 2 2 50
# 120 Predicted value: 4 4 70
# 121 Predicted value: 0 0 100
# 122 Predicted value: 2 2 50
# 123 Predicted value: 0 0 100
# 124 Predicted value: 6 6 forward
# 125 Predicted value: 5 5 80
# 126 Predicted value: 2 2 50
# 127 Predicted value: 4 4 70
# 128 Predicted value: 0 0 100
# 129 Predicted value: 3 3 60
# 130 Predicted value: 2 2 50
# 131 Predicted value: 5 5 80
# 132 Predicted value: 3 3 60
# 133 Predicted value: 2 2 50
# 134 Predicted value: 7 7 left
# 135 Predicted value: 4 4 70
# 136 Predicted value: 0 0 100
# 137 Predicted value: 6 6 forward
# 138 Predicted value: 4 4 70
# 139 Predicted value: 4 4 70
# 140 Predicted value: 2 2 50
# 141 Predicted value: 5 5 80
# 142 Predicted value: 5 5 80
# 143 Predicted value: 4 4 70
# 144 Predicted value: 3 3 60
# 145 Predicted value: 0 0 100
# 146 Predicted value: 7 7 left
# 147 Predicted value: 5 5 80
# 148 Predicted value: 1 1 30
# 149 Predicted value: 6 6 forward
# 150 Predicted value: 8 8 right
# 151 Predicted value: 5 5 80
# 152 Predicted value: 0 0 100
# 153 Predicted value: 0 0 100
# 154 Predicted value: 0 0 100
# 155 Predicted value: 2 2 50
# 156 Predicted value: 1 1 30
# 157 Predicted value: 1 1 30
# 158 Predicted value: 1 1 30
# 159 Predicted value: 2 2 50
# 160 Predicted value: 2 2 50
# 161 Predicted value: 5 5 80
# 162 Predicted value: 2 2 50
# 163 Predicted value: 4 4 70
# 164 Predicted value: 1 1 30
# 165 Predicted value: 2 2 50
# 166 Predicted value: 8 8 right
# 167 Predicted value: 8 8 right
# 168 Predicted value: 3 3 60
# 169 Predicted value: 5 5 80
# 170 Predicted value: 2 2 50
# 171 Predicted value: 1 1 30
# 172 Predicted value: 6 6 forward
# 173 Predicted value: 8 8 right
# 174 Predicted value: 1 1 30
# 175 Predicted value: 1 1 30
# 176 Predicted value: 4 4 70
# 177 Predicted value: 4 4 70
# 178 Predicted value: 2 2 50
# 179 Predicted value: 3 3 60
# 180 Predicted value: 2 1 50
# 181 Predicted value: 2 2 50
# 182 Predicted value: 2 2 50
# 183 Predicted value: 8 8 right
# 184 Predicted value: 2 2 50
# 185 Predicted value: 8 8 right
# 186 Predicted value: 1 1 30
# 187 Predicted value: 4 4 70
# 188 Predicted value: 5 3 80
# 189 Predicted value: 0 0 100
# 190 Predicted value: 3 3 60
# 191 Predicted value: 2 2 50
# 192 Predicted value: 3 3 60
# 193 Predicted value: 5 0 80
# 194 Predicted value: 1 1 30
# 195 Predicted value: 3 3 60
# 196 Predicted value: 2 2 50
# 197 Predicted value: 8 7 right
# 198 Predicted value: 0 0 100
# 199 Predicted value: 5 5 80
# 200 Predicted value: 4 4 70
# 201 Predicted value: 5 5 80
# 202 Predicted value: 2 2 50
# 203 Predicted value: 1 1 30
# 204 Predicted value: 8 8 right
# 205 Predicted value: 1 1 30
# 206 Predicted value: 6 6 forward
# 207 Predicted value: 6 6 forward
# 208 Predicted value: 4 4 70
# 209 Predicted value: 2 2 50
# 210 Predicted value: 3 3 60
# 211 Predicted value: 5 5 80
# 212 Predicted value: 2 2 50
# 213 Predicted value: 8 8 right
# 214 Predicted value: 0 0 100
# 215 Predicted value: 5 5 80
# 216 Predicted value: 4 4 70
# 217 Predicted value: 2 2 50
# 218 Predicted value: 0 0 100
# 219 Predicted value: 6 6 forward
# 220 Predicted value: 3 3 60
# 221 Predicted value: 1 1 30
# 222 Predicted value: 3 3 60
# 223 Predicted value: 4 4 70
# 224 Predicted value: 6 6 forward
# 225 Predicted value: 1 1 30
# 226 Predicted value: 0 0 100
# 227 Predicted value: 5 5 80
# 228 Predicted value: 3 3 60
# 229 Predicted value: 2 2 50
# 230 Predicted value: 1 1 30
# 231 Predicted value: 5 5 80
# 232 Predicted value: 6 6 forward
# 233 Predicted value: 5 2 80
# 234 Predicted value: 0 0 100
# 235 Predicted value: 6 6 forward
# 236 Predicted value: 4 4 70
# 237 Predicted value: 8 8 right
# 238 Predicted value: 5 5 80
# 239 Predicted value: 7 8 left
# 240 Predicted value: 6 6 forward
# 241 Predicted value: 2 2 50
# 242 Predicted value: 4 0 70
# 243 Predicted value: 4 4 70
# 244 Predicted value: 4 4 70
# 245 Predicted value: 5 5 80
# 246 Predicted value: 4 4 70
# 247 Predicted value: 5 5 80
# 248 Predicted value: 1 1 30
# 249 Predicted value: 4 4 70
# 250 Predicted value: 6 6 forward
# 251 Predicted value: 2 2 50
# 252 Predicted value: 1 1 30
# 253 Predicted value: 4 4 70
# 254 Predicted value: 5 5 80
# 255 Predicted value: 4 4 70
# 256 Predicted value: 5 5 80
# 257 Predicted value: 3 3 60
# 258 Predicted value: 4 4 70
# 259 Predicted value: 0 0 100
# 260 Predicted value: 4 4 70
# 261 Predicted value: 1 1 30
# 262 Predicted value: 0 2 100
# 263 Predicted value: 0 0 100
# 264 Predicted value: 2 3 50
# 265 Predicted value: 4 4 70
# 266 Predicted value: 3 3 60
# 267 Predicted value: 4 4 70
# 268 Predicted value: 3 3 60
# 269 Predicted value: 8 8 right
# 270 Predicted value: 2 2 50
# 271 Predicted value: 6 6 forward
# 272 Predicted value: 2 2 50
# 273 Predicted value: 4 4 70
# 274 Predicted value: 4 4 70
# 275 Predicted value: 2 2 50
# 276 Predicted value: 8 8 right
# 277 Predicted value: 6 6 forward
# 278 Predicted value: 3 3 60
# 279 Predicted value: 0 0 100
# 280 Predicted value: 2 2 50
# 281 Predicted value: 8 8 right
# 282 Predicted value: 5 5 80
# 283 Predicted value: 1 3 30
# 284 Predicted value: 8 7 right
# 285 Predicted value: 5 5 80
# 286 Predicted value: 4 4 70
# 287 Predicted value: 2 2 50
# 288 Predicted value: 3 3 60
# 289 Predicted value: 1 1 30
# 290 Predicted value: 4 4 70
# 291 Predicted value: 8 8 right
# 292 Predicted value: 0 0 100
# 293 Predicted value: 5 5 80
# 294 Predicted value: 8 8 right
# 295 Predicted value: 4 4 70
# 296 Predicted value: 4 5 70
# 297 Predicted value: 1 1 30
# 298 Predicted value: 4 4 70
# 299 Predicted value: 1 1 30
# 300 Predicted value: 2 2 50
# 301 Predicted value: 5 5 80
# 302 Predicted value: 0 0 100
# 303 Predicted value: 4 4 70
# 304 Predicted value: 1 1 30
# 305 Predicted value: 1 1 30
# 306 Predicted value: 4 4 70
# 307 Predicted value: 6 6 forward
# 308 Predicted value: 0 0 100
# 309 Predicted value: 5 5 80
# 310 Predicted value: 8 7 right
# 311 Predicted value: 2 2 50
# 312 Predicted value: 1 1 30
# 313 Predicted value: 8 8 right
# 314 Predicted value: 4 4 70
# 315 Predicted value: 0 0 100
# 316 Predicted value: 0 0 100
# 317 Predicted value: 6 6 forward
# 318 Predicted value: 2 2 50
# 319 Predicted value: 5 5 80
# 320 Predicted value: 1 1 30
# 321 Predicted value: 2 2 50
# 322 Predicted value: 4 1 70
# 323 Predicted value: 4 4 70
# 324 Predicted value: 5 5 80
# 325 Predicted value: 1 5 30
# 326 Predicted value: 1 1 30
# 327 Predicted value: 4 4 70
# 328 Predicted value: 6 6 forward
# 329 Predicted value: 1 1 30
# 330 Predicted value: 8 8 right
# 331 Predicted value: 1 1 30
# 332 Predicted value: 3 3 60
# 333 Predicted value: 6 6 forward
# 334 Predicted value: 7 7 left
# 335 Predicted value: 5 5 80
# 336 Predicted value: 4 2 70
# 337 Predicted value: 1 2 30
# 338 Predicted value: 1 1 30
# 339 Predicted value: 0 1 100
# 340 Predicted value: 0 0 100
# 341 Predicted value: 3 3 60
# 342 Predicted value: 0 0 100
# 343 Predicted value: 3 3 60
# 344 Predicted value: 5 5 80
# 345 Predicted value: 2 2 50
# 346 Predicted value: 1 1 30
# 347 Predicted value: 3 3 60
# 348 Predicted value: 1 1 30
# 349 Predicted value: 4 4 70
# 350 Predicted value: 4 4 70
# 351 Predicted value: 7 7 left
# 352 Predicted value: 3 3 60
# 353 Predicted value: 3 3 60
# 354 Predicted value: 1 1 30
# 355 Predicted value: 3 3 60
# 356 Predicted value: 2 2 50
# 357 Predicted value: 2 2 50
# 358 Predicted value: 4 4 70
# 359 Predicted value: 5 5 80
# 360 Predicted value: 2 2 50
# 361 Predicted value: 6 6 forward
# 362 Predicted value: 4 4 70
# 363 Predicted value: 6 6 forward
# 364 Predicted value: 3 3 60
# 365 Predicted value: 0 0 100
# 366 Predicted value: 2 2 50
# 367 Predicted value: 1 1 30
# 368 Predicted value: 2 2 50
# 369 Predicted value: 0 5 100
# 370 Predicted value: 2 2 50
# 371 Predicted value: 3 3 60
# 372 Predicted value: 2 2 50
# 373 Predicted value: 1 1 30
# 374 Predicted value: 2 2 50
# 375 Predicted value: 1 1 30
# 376 Predicted value: 1 1 30
# 377 Predicted value: 6 6 forward
# 378 Predicted value: 2 2 50
# 379 Predicted value: 6 6 forward
# 380 Predicted value: 2 2 50
# 381 Predicted value: 2 2 50
# 382 Predicted value: 8 7 right
# 383 Predicted value: 1 1 30
# 384 Predicted value: 2 2 50
# 385 Predicted value: 2 2 50
# 386 Predicted value: 2 2 50
# 387 Predicted value: 2 2 50
# 388 Predicted value: 3 3 60
# 389 Predicted value: 5 2 80
# 390 Predicted value: 1 2 30
# 391 Predicted value: 6 6 forward
# 392 Predicted value: 2 2 50
# 393 Predicted value: 6 6 forward
# 394 Predicted value: 2 5 50
# 395 Predicted value: 5 5 80
# 396 Predicted value: 3 3 60
# 397 Predicted value: 4 4 70
# 398 Predicted value: 1 1 30
# 399 Predicted value: 0 0 100
# 400 Predicted value: 1 1 30
# 401 Predicted value: 7 7 left
# 402 Predicted value: 1 1 30
# 403 Predicted value: 5 5 80
# 404 Predicted value: 4 4 70
# 405 Predicted value: 7 7 left
# 406 Predicted value: 5 5 80
# 407 Predicted value: 1 1 30
# 408 Predicted value: 2 2 50
# 409 Predicted value: 4 4 70
# 410 Predicted value: 5 5 80
# 411 Predicted value: 4 4 70
# 412 Predicted value: 3 3 60
# 413 Predicted value: 4 4 70
# 414 Predicted value: 2 2 50
# 415 Predicted value: 8 8 right
# 416 Predicted value: 4 4 70
# 417 Predicted value: 1 1 30
# 418 Predicted value: 8 8 right
# 419 Predicted value: 5 5 80
# 420 Predicted value: 5 5 80
# 421 Predicted value: 1 1 30
# 422 Predicted value: 0 0 100
# 423 Predicted value: 3 3 60
# 424 Predicted value: 2 2 50
# 425 Predicted value: 2 2 50
# 426 Predicted value: 3 3 60
# 427 Predicted value: 2 2 50
# 428 Predicted value: 1 1 30
# 429 Predicted value: 3 3 60
# 430 Predicted value: 5 5 80
# 431 Predicted value: 2 2 50
# 432 Predicted value: 1 1 30
# 433 Predicted value: 4 5 70
# 434 Predicted value: 2 2 50
# 435 Predicted value: 3 3 60
# 436 Predicted value: 6 6 forward
# 437 Predicted value: 4 4 70
# 438 Predicted value: 2 2 50
# 439 Predicted value: 4 4 70
# 440 Predicted value: 1 1 30
# 441 Predicted value: 6 3 forward
# 442 Predicted value: 1 1 30
# 443 Predicted value: 2 2 50
# 444 Predicted value: 6 6 forward
# 445 Predicted value: 4 4 70
# 446 Predicted value: 7 7 left
# 447 Predicted value: 4 4 70
# 448 Predicted value: 1 1 30
# 449 Predicted value: 1 1 30
# 450 Predicted value: 8 8 right
# 451 Predicted value: 1 1 30

# %%
# Out:
# [10, 14, 17, 26, 67, 75, 95, 98, 106, 180, 188, 193, 197, 233, 239, 242, 262, 264, 283, 284, 296, 310, 322, 325, 336, 337, 339, 369, 382, 389, 390, 394, 433, 441]
# Test accuracy: 14.72%

# %%
x = 99


im = inv_normalize(test_set[x][0])
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));
test_set[x][0].shape

CNNmodel.eval()
with torch.no_grad():
    new_pred = CNNmodel(test_set[x][0].view(1,3,224,224)).argmax()
print(f'Predicted value: {new_pred.item()} {test_set[x][1]}')
# Out:
# Predicted value: 1 1

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn  # for heatmaps

# Create a loader for the entire the test set
test_load_all = DataLoader(val_set, batch_size=2000, shuffle=False)
false=[]
x=0
with torch.no_grad():
    correct = 0
    for x, X_test, y_test in test_load_all:
        y_val = CNNmodel(X_test)
        predicted = torch.max(y_val,1)[1]
        correct += (predicted == y_test).sum()
        if new_pred.item() != test_set[x][1]:
            false.append(x)
arr = confusion_matrix(y_test.view(-1), predicted.view(-1))
df_cm = pd.DataFrame(arr, class_names, class_names)
plt.figure(figsize = (9,6))
sn.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.xlabel("prediction")
plt.ylabel("label (ground truth)")
plt.show();

# %%
print(false)
# Out:
# [1]
